# %% [markdown]
# ## AU DEEP LEARNING COURSE:
# ### A minimal training routing using pre-defined CNN models
# This nodebook sets up a simple training routine. To keep it simple, it contains no validation routine, which you would normally incorporate as part of the training loop.

# %% [markdown]
# ### We need some training-data.
# The first part downloads some traing data, unfortunatly the download-script it is not very stable :-/
#
# Do you already have some training data? Great! Then you can skip this part - You just have to make sure the images are in individual folders, where the folder name indicate the class i.e.

# %% [raw]
# ```
# ./Trainingdata/
#               |-> dog
#               |    |-> dog1.jpg
#               |    |-> dog2.jpg
#               |    |-> ...
#               |-> cat
#               |    |-> cat1.jpg
#               |    |-> cat2.jpg
#               |    |-> ...
#               |-> horse
#                    |-> horse1.jpg
#                    |-> horse2.jpg
#                    |-> ...
# ```

# %%
# path for training data
traindir = 'Trainingdata'

# %%
import requests
import re
import json
import time
import os

def createifnotexist(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)

def search(keywords, outputfolder='./', max_results=None):
    outdir = os.path.join(outputfolder,keywords)
    createifnotexist(outdir)
    n_results = 0

    url = 'https://duckduckgo.com/'
    params = {
    	'q': keywords
    }

    #   First make a request to above URL, and parse out the 'vqd'
    #   This is a special token, which should be used in the subsequent request
    res = requests.post(url, data=params)
    searchObj = re.search(r'vqd=([\d-]+)\&', res.text, re.M|re.I)

    if not searchObj:
        return -1

    headers = {
        'authority': 'duckduckgo.com',
        'accept': 'application/json, text/javascript, */*; q=0.01',
        'sec-fetch-dest': 'empty',
        'x-requested-with': 'XMLHttpRequest',
        'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'cors',
        'referer': 'https://duckduckgo.com/',
        'accept-language': 'en-US,en;q=0.9',
    }

    params = (
        ('l', 'us-en'),
        ('o', 'json'),
        ('q', keywords),
        ('vqd', searchObj.group(1)),
        ('f', ',,,'),
        ('p', '1'),
        ('v7exp', 'a'),
    )

    requestUrl = url + "i.js"

    while True:
        while True:
            try:
                res = requests.get(requestUrl, headers=headers, params=params)
                data = json.loads(res.text)
                break
            except ValueError as e:
                time.sleep(5)
                continue

        for x in data["results"]:
            #os.system('wget '+x['image']+' -P "'+keywords+'"')
            os.system('wget "'+x['image']+'" --no-verbose -P "'+outdir+'"')
            n_results+=1
            if max_results is not None:
                if n_results>=max_results: return

        if "next" not in data:
            exit(0)

        requestUrl = url + data["next"]

# %%
if not os.path.exists(os.path.join(traindir, "Dog")):
    search("Dog", outputfolder=traindir, max_results=100)
if not os.path.exists(os.path.join(traindir, "Cat")):
    search("Cat", outputfolder=traindir, max_results=100)
# Out:
# 2022-09-28 17:58:07 URL:https://www.thesprucepets.com/thmb/AlsaZ1vMyplHqJkbe-iKeyzJwRY=/4368x2912/filters:fill(auto,1)/burmese-cat-love-85151671-5c87d723c9e77c0001a3e5ae.jpg [1287189/1287189] -> "Trainingdata/Cat/burmese-cat-love-85151671-5c87d723c9e77c0001a3e5ae.jpg" [1]
# 2022-09-28 17:58:07 URL:https://www.readersdigest.ca/wp-content/uploads/2019/11/most-affectionate-cat-breeds-russian-blue.jpg [163154/163154] -> "Trainingdata/Cat/most-affectionate-cat-breeds-russian-blue.jpg" [1]
# 2022-09-28 17:58:08 URL:http://images6.fanpop.com/image/photos/34300000/Kitten-cats-34352405-1600-1200.jpg [383197/383197] -> "Trainingdata/Cat/Kitten-cats-34352405-1600-1200.jpg" [1]
# 2022-09-28 17:58:08 URL:https://cdn.vox-cdn.com/thumbor/3GvnfOvGZB3paInd57sdlY1Hvu8=/0x0:1006x1014/1200x0/filters:focal(0x0:1006x1014):no_upscale()/cdn.vox-cdn.com/uploads/chorus_asset/file/22438217/Screen_Shot_2021_04_12_at_8.16.17_AM.png [195574/195574] -> "Trainingdata/Cat/Screen_Shot_2021_04_12_at_8.16.17_AM.png" [1]
# 2022-09-28 17:58:08 URL:https://petsreporter.com/wp-content/uploads/2020/11/Weird-Cat-Behaviors-Explained-6-1.jpg [547951/547951] -> "Trainingdata/Cat/Weird-Cat-Behaviors-Explained-6-1.jpg" [1]
# 2022-09-28 17:58:10 URL:https://bestpetsvet.com/wp-content/uploads/2019/02/cat-2146089_1280.jpg [187561/187561] -> "Trainingdata/Cat/cat-2146089_1280.jpg" [1]
# 2022-09-28 17:58:11 URL:https://meow.af/wp-content/uploads/2020/11/hipsfeature.png [1568439/1568439] -> "Trainingdata/Cat/hipsfeature.png" [1]
# 2022-09-28 17:58:11 URL:https://pbs.twimg.com/media/Dys_ovoXcAERzFA.jpg:large [716750/716750] -> "Trainingdata/Cat/Dys_ovoXcAERzFA.jpg:large" [1]
# 2022-09-28 17:58:12 URL:https://www.abyssiniancat.org/wp-content/uploads/2017/01/Abyssinian-Cat-with-Basket.jpg [1907763/1907763] -> "Trainingdata/Cat/Abyssinian-Cat-with-Basket.jpg" [1]
# 2022-09-28 17:58:12 URL:https://wallup.net/wp-content/uploads/2019/09/1667-beautiful-gray-cat.jpg [998867] -> "Trainingdata/Cat/1667-beautiful-gray-cat.jpg" [1]
# 2022-09-28 17:58:13 URL:https://catpedia.net/wp-content/uploads/2017/12/Oriental-Cinnamon-and-Fawn-cat.jpg [850956/850956] -> "Trainingdata/Cat/Oriental-Cinnamon-and-Fawn-cat.jpg" [1]
# 2022-09-28 17:58:13 URL:https://preview.redd.it/5yuv72p1clj11.jpg?auto=webp&s=e1ff8dcaca99dd0a954e5c53485c1afc47a5bfdc [561346/561346] -> "Trainingdata/Cat/5yuv72p1clj11.jpg?auto=webp&s=e1ff8dcaca99dd0a954e5c53485c1afc47a5bfdc" [1]
# 2022-09-28 17:58:13 URL:https://lbpost.com/hi-lo/wp-content/uploads/2017/09/LOKI_in_the_window.jpg [392795/392795] -> "Trainingdata/Cat/LOKI_in_the_window.jpg" [1]
# 2022-09-28 17:58:13 URL:http://wallup.net/wp-content/uploads/2017/03/28/421924-cat-animals.jpg [963587] -> "Trainingdata/Cat/421924-cat-animals.jpg" [1]
# 2022-09-28 17:58:18 URL:https://www.hdnicewallpapers.com/Walls/Big/Cat/Pretty_Cat_Pic_Download.jpg [318419/318419] -> "Trainingdata/Cat/Pretty_Cat_Pic_Download.jpg" [1]
# 2022-09-28 17:58:18 URL:https://wallup.net/wp-content/uploads/2019/09/559734-european-wild-cat.jpg [441981] -> "Trainingdata/Cat/559734-european-wild-cat.jpg" [1]
# 2022-09-28 17:58:18 URL:https://www.thesprucepets.com/thmb/5tDHikYVxrJXwQCgVhacYo5PS4g=/2121x1414/filters:fill(auto,1)/Madelein_WolfGettyImages-845007724-cff4995e51a749e0a69f529c75447f5b.jpg [311831/311831] -> "Trainingdata/Cat/Madelein_WolfGettyImages-845007724-cff4995e51a749e0a69f529c75447f5b.jpg" [1]
# 2022-09-28 17:58:18 URL:https://img.thrfun.com/img/220/040/what_breed_is_my_cat_tx7.jpg [237561/237561] -> "Trainingdata/Cat/what_breed_is_my_cat_tx7.jpg" [1]
# 2022-09-28 17:58:19 URL:https://preview.redd.it/7cu5lub5okl21.jpg?auto=webp&s=5ad2cf86d114e14c63cbd7bfc57124f17abbc880 [1568401/1568401] -> "Trainingdata/Cat/7cu5lub5okl21.jpg?auto=webp&s=5ad2cf86d114e14c63cbd7bfc57124f17abbc880" [1]
# 2022-09-28 17:58:19 URL:https://www.publicdomainpictures.net/pictures/180000/velka/cat-1464103447LmK.jpg [546448/546448] -> "Trainingdata/Cat/cat-1464103447LmK.jpg" [1]
# 2022-09-28 17:58:19 URL:https://petclassifieds.com/wp-content/uploads/2020/08/2F11E558-97CA-463D-A3A8-CD06F47DDCC1-scaled.jpeg [153657/153657] -> "Trainingdata/Cat/2F11E558-97CA-463D-A3A8-CD06F47DDCC1-scaled.jpeg" [1]
# 2022-09-28 17:58:19 URL:https://www.publicdomainpictures.net/pictures/50000/velka/cat-1373446292aWW.jpg [423745/423745] -> "Trainingdata/Cat/cat-1373446292aWW.jpg" [1]
# 2022-09-28 17:58:20 URL:http://images6.fanpop.com/image/photos/41200000/Cat-cats-41239805-1600-900.jpg [339652/339652] -> "Trainingdata/Cat/Cat-cats-41239805-1600-900.jpg" [1]
# 2022-09-28 17:58:21 URL:http://images2.fanpop.com/image/photos/13400000/Cat-cats-13494223-2304-1728.jpg [363896/363896] -> "Trainingdata/Cat/Cat-cats-13494223-2304-1728.jpg" [1]
# 2022-09-28 17:58:21 URL:https://catvills.com/wp-content/uploads/2020/02/dumbest-cat-breeds-f-1.jpg [76146/76146] -> "Trainingdata/Cat/dumbest-cat-breeds-f-1.jpg" [1]
# 2022-09-28 17:58:22 URL:https://img.thrfun.com/img/015/948/cat_meowing_tx.jpg [136025/136025] -> "Trainingdata/Cat/cat_meowing_tx.jpg" [1]
# 2022-09-28 17:58:22 URL:https://www.100hdwallpapers.com/wallpapers/2560x1600/curious_cat-widescreen_wallpapers.jpg [962758] -> "Trainingdata/Cat/curious_cat-widescreen_wallpapers.jpg" [1]
# 2022-09-28 17:58:22 URL:http://images2.fanpop.com/image/photos/13400000/Cat-cats-13494271-1600-1200.jpg [504248/504248] -> "Trainingdata/Cat/Cat-cats-13494271-1600-1200.jpg" [1]
# 2022-09-28 17:58:23 URL:http://images6.fanpop.com/image/photos/36800000/Cat-cats-36840812-1200-1075.jpg [515876/515876] -> "Trainingdata/Cat/Cat-cats-36840812-1200-1075.jpg" [1]
# 2022-09-28 17:58:23 URL:https://www.publicdomainpictures.net/pictures/50000/velka/cat-13710476729kg.jpg [520648/520648] -> "Trainingdata/Cat/cat-13710476729kg.jpg" [1]
# 2022-09-28 17:58:24 URL:https://imunopet.com/wp-content/uploads/2021/05/cat.jpg [174540/174540] -> "Trainingdata/Cat/cat.jpg" [1]
# 2022-09-28 17:58:26 URL:https://pets4life.com.au/wp-content/uploads/2019/02/meggs.jpg [76504/76504] -> "Trainingdata/Cat/meggs.jpg" [1]
# 2022-09-28 17:58:29 URL:https://meowcatrescue.org/wp-content/uploads/2020/07/Xena-2-Cropped.jpg [449692/449692] -> "Trainingdata/Cat/Xena-2-Cropped.jpg" [1]
# 2022-09-28 17:58:29 URL:https://wallup.net/wp-content/uploads/2018/10/07/58245-cat-kittens-babies-face-eyes.jpg [305823] -> "Trainingdata/Cat/58245-cat-kittens-babies-face-eyes.jpg" [1]
# 2022-09-28 17:58:30 URL:https://preview.redd.it/q5ilvl3p3qxy.jpg?auto=webp&s=c568bc0e67f720cdd0653e9dd0f1535e1bd192f7 [1221321/1221321] -> "Trainingdata/Cat/q5ilvl3p3qxy.jpg?auto=webp&s=c568bc0e67f720cdd0653e9dd0f1535e1bd192f7" [1]
# 2022-09-28 17:58:30 URL:https://blog.healthypawspetinsurance.com//wp-content/uploads/outdoor_feral_cat_nature-1012x1024.jpg [246259/246259] -> "Trainingdata/Cat/outdoor_feral_cat_nature-1012x1024.jpg" [1]
# 2022-09-28 17:58:30 URL:https://dinoanimals.com/wp-content/uploads/2021/01/Burmese-cat-16.jpg [59925/59925] -> "Trainingdata/Cat/Burmese-cat-16.jpg" [1]
# 2022-09-28 17:58:31 URL:https://newseu.cgtn.com/news/2020-07-28/Pet-cat-becomes-first-animal-in-the-UK-to-test-positive-for-COVID-19-Stu0H0T6Gk/img/9ff85c8aa3cd4670ae6ac08c4327deaf/9ff85c8aa3cd4670ae6ac08c4327deaf-1920.png [4974986/4974986] -> "Trainingdata/Cat/9ff85c8aa3cd4670ae6ac08c4327deaf-1920.png" [1]
# 2022-09-28 17:58:31 URL:https://animalcare.knowallnow.com/wp-content/uploads/2020/12/gato_viejo-1.jpg [109309/109309] -> "Trainingdata/Cat/gato_viejo-1.jpg" [1]
# 2022-09-28 17:58:31 URL:https://imgix.bustle.com/uploads/getty/2019/4/30/a9f724a3-70ad-45b4-9d8b-034de4e3597c-getty-459409952.jpg?w=1200&h=630&fit=crop&crop=faces&fm=jpg [89971/89971] -> "Trainingdata/Cat/a9f724a3-70ad-45b4-9d8b-034de4e3597c-getty-459409952.jpg?w=1200&h=630&fit=crop&crop=faces&fm=jpg" [1]
# 2022-09-28 17:58:33 URL:https://www.thinkingoutsidethecage.org/wp-content/uploads/2019/02/Cat-Behavior-Solutions-1024x683.jpg [519080/519080] -> "Trainingdata/Cat/Cat-Behavior-Solutions-1024x683.jpg" [1]
# 2022-09-28 17:58:33 URL:https://media-cldnry.s-nbcnews.com/image/upload/t_social_share_1200x630_center,f_auto,q_auto:best/streams/2013/July/130731/6C8464723-ss-130731-AT-tease.jpg [148682/148682] -> "Trainingdata/Cat/6C8464723-ss-130731-AT-tease.jpg" [1]
# 2022-09-28 17:58:34 URL:https://img.thrfun.com/img/085/346/cat_on_a_couch_x1.jpg [272882/272882] -> "Trainingdata/Cat/cat_on_a_couch_x1.jpg" [1]
# 2022-09-28 17:58:34 URL:https://wallup.net/wp-content/uploads/2016/01/194546-animals-cat.jpg [475755] -> "Trainingdata/Cat/194546-animals-cat.jpg" [1]
# 2022-09-28 17:58:34 URL:https://faunafocus.files.wordpress.com/2021/01/rusty-spotted-cat.png?w=956&h=956&crop=1 [1213834/1213834] -> "Trainingdata/Cat/rusty-spotted-cat.png?w=956&h=956&crop=1" [1]
# 2022-09-28 17:58:34 URL:https://catvills.com/wp-content/uploads/2017/08/litter-train-a-cat-f-850x657.jpg [68106/68106] -> "Trainingdata/Cat/litter-train-a-cat-f-850x657.jpg" [1]
# 2022-09-28 17:58:35 URL:https://www.publicdomainpictures.net/pictures/40000/velka/cat-13625446795Ja.jpg [771079/771079] -> "Trainingdata/Cat/cat-13625446795Ja.jpg" [1]
# 2022-09-28 17:58:36 URL:https://www.vets4pets.com/siteassets/species/cat/cat-on-fence.jpg?w=585&scale=down [3015976/3015976] -> "Trainingdata/Cat/cat-on-fence.jpg?w=585&scale=down" [1]
# 2022-09-28 17:58:36 URL:https://wallup.net/wp-content/uploads/2016/10/12/263986-cat-kittens.jpg [481132] -> "Trainingdata/Cat/263986-cat-kittens.jpg" [1]
# 2022-09-28 17:58:37 URL:https://www.publicdomainpictures.net/pictures/190000/velka/cat-1470296150LtQ.jpg [450053/450053] -> "Trainingdata/Cat/cat-1470296150LtQ.jpg" [1]
# 2022-09-28 17:58:37 URL:https://preview.redd.it/d388vhp0j7t21.jpg?auto=webp&s=7f867b75b7782ba5c7dcd3e347cbd125beb7d429 [1512697/1512697] -> "Trainingdata/Cat/d388vhp0j7t21.jpg?auto=webp&s=7f867b75b7782ba5c7dcd3e347cbd125beb7d429" [1]
# 2022-09-28 17:58:38 URL:http://wallpoper.com/cgi-sys/suspendedpage.cgi [7620] -> "Trainingdata/Cat/cats-kittens_00397702.jpg" [1]
# 2022-09-28 17:58:40 URL:https://beachesanimalhospital.com/wp-content/uploads/2020/01/cat-4436152_1280.jpg [142741/142741] -> "Trainingdata/Cat/cat-4436152_1280.jpg" [1]
# 2022-09-28 17:58:40 URL:https://preview.redd.it/djqnhkd07gd41.jpg?auto=webp&s=0869b6e5f13a836b1f3a0874dd7a0fb8bccddeb4 [792215/792215] -> "Trainingdata/Cat/djqnhkd07gd41.jpg?auto=webp&s=0869b6e5f13a836b1f3a0874dd7a0fb8bccddeb4" [1]
# 2022-09-28 17:58:40 URL:https://d.ibtimes.co.uk/en/full/1654558/pet-cat.jpg [842509/842509] -> "Trainingdata/Cat/pet-cat.jpg" [1]
# 2022-09-28 17:58:40 URL:https://static.independent.co.uk/2021/04/22/13/newFile-6.jpg?width=1200&auto=webp&quality=75 [89147/89147] -> "Trainingdata/Cat/newFile-6.jpg?width=1200&auto=webp&quality=75" [1]
# 2022-09-28 17:58:40 URL:https://pbs.twimg.com/media/DdRPa1nUwAA4V4l.jpg:large [231711/231711] -> "Trainingdata/Cat/DdRPa1nUwAA4V4l.jpg:large" [1]
# 2022-09-28 17:58:41 URL:https://preview.redd.it/maj8qpsakbq31.jpg?auto=webp&s=bb6a3e0e2ea5090d8ee99637af24baf54f126cef [1103550/1103550] -> "Trainingdata/Cat/maj8qpsakbq31.jpg?auto=webp&s=bb6a3e0e2ea5090d8ee99637af24baf54f126cef" [1]
# 2022-09-28 17:58:42 URL:https://wallup.net/wp-content/uploads/2016/03/12/305164-nature-cat.jpg [657201] -> "Trainingdata/Cat/305164-nature-cat.jpg" [1]
# 2022-09-28 17:58:42 URL:http://images2.fanpop.com/image/photos/13400000/Cat-cats-13494053-1600-1200.jpg [1238210/1238210] -> "Trainingdata/Cat/Cat-cats-13494053-1600-1200.jpg" [1]
# 2022-09-28 17:58:42 URL:https://www.publicdomainpictures.net/pictures/30000/velka/kitten.jpg [519899/519899] -> "Trainingdata/Cat/kitten.jpg" [1]
# 2022-09-28 17:58:42 URL:https://www.advantagepetcare.com.au/sites/g/files/adhwdz311/files/styles/paragraph_image/public/2019-06/34_cat_adult_bringing_adult_cat_home-edited.jpg?itok=j_ssHG2z [51882/51882] -> "Trainingdata/Cat/34_cat_adult_bringing_adult_cat_home-edited.jpg?itok=j_ssHG2z" [1]
# 2022-09-28 17:58:42 URL:https://catvills.com/wp-content/uploads/2021/03/nature-inspired-cat-names-1.jpg [56999/56999] -> "Trainingdata/Cat/nature-inspired-cat-names-1.jpg" [1]
# 2022-09-28 17:58:42 URL:https://www.shutterbug.com/images/photo_post/[uid]/2_20.jpg [1503361/1503361] -> "Trainingdata/Cat/2_20.jpg" [1]
# 2022-09-28 17:58:42 URL:https://www.stray-cat-advice.com/wp-content/uploads/2018/05/httpspixabay.comenusersFritz_the_Cat-2.jpg [210275] -> "Trainingdata/Cat/httpspixabay.comenusersFritz_the_Cat-2.jpg" [1]
# 2022-09-28 17:58:43 URL:http://wallup.net/wp-content/uploads/2016/10/12/354444-cat-village-Poland-white-nature.jpg [418177] -> "Trainingdata/Cat/354444-cat-village-Poland-white-nature.jpg" [1]
# 2022-09-28 17:58:43 URL:https://www.wideopenpets.com/wp-content/uploads/2021/06/bigstock-Sacred-Cat-Of-Burma-Birman-Ca-417631351-1536x1021.jpg [192773/192773] -> "Trainingdata/Cat/bigstock-Sacred-Cat-Of-Burma-Birman-Ca-417631351-1536x1021.jpg" [1]
# 2022-09-28 17:58:43 URL:https://pngimg.com/uploads/cat/cat_PNG50428.png [4269475/4269475] -> "Trainingdata/Cat/cat_PNG50428.png" [1]
# 2022-09-28 17:58:43 URL:https://images.wagwalkingweb.com/media/daily_wag/name_guides/%7Bslug%7D/hero/1619563246.558215/thandy-yung-c2a8thlutsu-unsplash.jpg [499750/499750] -> "Trainingdata/Cat/thandy-yung-c2a8thlutsu-unsplash.jpg" [1]
# 2022-09-28 17:58:44 URL:https://burmesecatclub.com/app/uploads/2017/08/27b-Chocolate-1-1.gif [1405544/1405544] -> "Trainingdata/Cat/27b-Chocolate-1-1.gif" [1]
# 2022-09-28 17:58:44 URL:https://static.themoscowtimes.com/image/1360/4e/26.jpg [219521/219521] -> "Trainingdata/Cat/26.jpg" [1]
# 2022-09-28 17:58:44 URL:https://live.staticflickr.com/2089/2060482953_97115e16c0_b.jpg [195059] -> "Trainingdata/Cat/2060482953_97115e16c0_b.jpg" [1]
# 2022-09-28 17:58:44 URL:https://www.infoplease.com/sites/infoplease.com/files/2020-08/cat-breeds.jpg [238538/238538] -> "Trainingdata/Cat/cat-breeds.jpg" [1]
# 2022-09-28 17:58:45 URL:http://i.huffpost.com/gen/1673586/images/o-CAT-PARLIAMENT-facebook.jpg [258686/258686] -> "Trainingdata/Cat/o-CAT-PARLIAMENT-facebook.jpg" [1]
# 2022-09-28 17:58:45 URL:http://2.bp.blogspot.com/_LDF9z4ZzZHo/TP__vW9O3mI/AAAAAAAAAEg/XNK0nLmM_Tk/s1600/1600cat_5008.jpg [418629/418629] -> "Trainingdata/Cat/1600cat_5008.jpg" [1]
# 2022-09-28 17:58:45 URL:https://preview.redd.it/ho7dhybltyp31.jpg?auto=webp&s=d050644ac2f54eb81e8d60dc2c3ef43b47e51fec [830352/830352] -> "Trainingdata/Cat/ho7dhybltyp31.jpg?auto=webp&s=d050644ac2f54eb81e8d60dc2c3ef43b47e51fec" [1]
# 2022-09-28 17:58:45 URL:https://purrfectcatbreeds.com/wp-content/uploads/2020/03/abyssinian-cat.jpg [29278] -> "Trainingdata/Cat/abyssinian-cat.jpg" [1]
# 2022-09-28 17:58:46 URL:https://www.historicmysteries.com/wp-content/uploads/2016/10/Black-cat-superstition-.jpg [96732/96732] -> "Trainingdata/Cat/Black-cat-superstition-.jpg" [1]
# 2022-09-28 17:58:46 URL:https://img.apmcdn.org/0108f2c0dacf1c3910bd6234980bf5d093112572/widescreen/cb8174-20150729-cat.jpg [70782/70782] -> "Trainingdata/Cat/cb8174-20150729-cat.jpg" [1]
# 2022-09-28 17:58:47 URL:https://cdn.vox-cdn.com/thumbor/_eVDct1N20zI3d7PWdiqfBmOszI=/0x123:1300x854/1600x900/cdn.vox-cdn.com/uploads/chorus_image/image/46284528/cat-cafe.0.0.jpg [164985/164985] -> "Trainingdata/Cat/cat-cafe.0.0.jpg" [1]
# 2022-09-28 17:58:47 URL:https://preview.redd.it/xi8uarv6wt921.jpg?auto=webp&s=25c0c87c8ccf835168f00fcbfe50388880b5a409 [433997/433997] -> "Trainingdata/Cat/xi8uarv6wt921.jpg?auto=webp&s=25c0c87c8ccf835168f00fcbfe50388880b5a409" [1]
# 2022-09-28 17:58:50 URL:http://www.kidssearch.com/picsearch/images/cat-pic-900x900-3f0c6fb.png [912967/912967] -> "Trainingdata/Cat/cat-pic-900x900-3f0c6fb.png" [1]
# 2022-09-28 17:58:51 URL:http://wallup.net/wp-content/uploads/2016/10/12/275521-cat-face-eyes.jpg [1039188] -> "Trainingdata/Cat/275521-cat-face-eyes.jpg" [1]
# 2022-09-28 17:58:53 URL:https://meowcatrescue.org/wp-content/uploads/2020/07/Coal-Cropped.jpeg [394917/394917] -> "Trainingdata/Cat/Coal-Cropped.jpeg" [1]
# 2022-09-28 17:58:55 URL:https://hotlineforwildlife.org/wp-content/uploads/2018/10/Fat-Cat-.jpg [448039/448039] -> "Trainingdata/Cat/Fat-Cat-.jpg" [1]
# 2022-09-28 17:58:55 URL:https://resources.stuff.co.nz/content/dam/images/1/f/8/n/n/e/image.related.StuffLandscapeSixteenByNine.1420x800.1f8iuu.png/1478140746024.jpg [76819/76819] -> "Trainingdata/Cat/1478140746024.jpg" [1]
# 2022-09-28 17:58:55 URL:https://www.wideopenpets.com/wp-content/uploads/2021/01/Black-Cat-Breeds.png [1016430/1016430] -> "Trainingdata/Cat/Black-Cat-Breeds.png" [1]
# 2022-09-28 17:58:56 URL:https://img2.grunge.com/img/gallery/the-dumbest-cat-breed-in-the-world/the-stupid-cat-was-inside-you-all-along-1575042129.jpg [104926/104926] -> "Trainingdata/Cat/the-stupid-cat-was-inside-you-all-along-1575042129.jpg" [1]
# 2022-09-28 17:58:56 URL:http://wallup.net/wp-content/uploads/2016/01/198519-animals-cat-yawning.jpg [704762] -> "Trainingdata/Cat/198519-animals-cat-yawning.jpg" [1]
# 2022-09-28 17:58:56 URL:https://jooinn.com/images/curious-cat-6.jpg [246871/246871] -> "Trainingdata/Cat/curious-cat-6.jpg" [1]
# 2022-09-28 17:58:57 URL:http://wallpoper.com/cgi-sys/suspendedpage.cgi [7620] -> "Trainingdata/Cat/cats-kittens_00293050.jpg" [1]
# 2022-09-28 17:58:58 URL:https://wallup.net/wp-content/uploads/2019/09/1025499-cute-animal-cat-yellow.jpg [230456] -> "Trainingdata/Cat/1025499-cute-animal-cat-yellow.jpg" [1]
# 2022-09-28 17:58:58 URL:https://images2.minutemediacdn.com/image/upload/c_fill,g_auto,h_1248,w_2220/f_auto,q_auto,w_1100/v1555345877/shape/mentalfloss/istock_000072600763_small.jpg [56338/56338] -> "Trainingdata/Cat/istock_000072600763_small.jpg" [1]
# 2022-09-28 17:58:58 URL:http://azure.wgp-cdn.co.uk/app-yourcat/posts/iStock-1026612064.jpg?&width=1200&height=630&mode=crop [70177/70177] -> "Trainingdata/Cat/iStock-1026612064.jpg?&width=1200&height=630&mode=crop" [1]
# 2022-09-28 17:58:58 URL:https://upload.wikimedia.org/wikipedia/commons/thumb/7/74/Cat_August_2010-3.jpg/800px-Cat_August_2010-3.jpg [91262/91262] -> "Trainingdata/Cat/800px-Cat_August_2010-3.jpg" [1]
# 2022-09-28 17:58:58 URL:https://static.themoscowtimes.com/image/1360/22/cat-hiller-russia.jpg [210590/210590] -> "Trainingdata/Cat/cat-hiller-russia.jpg" [1]
# 2022-09-28 17:58:59 URL:http://wallup.net/wp-content/uploads/2016/10/12/381113-animals-cat-photography.jpg [333931] -> "Trainingdata/Cat/381113-animals-cat-photography.jpg" [1]
# 2022-09-28 17:59:00 URL:https://fit-cats.com/wp-content/uploads/2020/02/cat-relaxing-1024x576.jpg [70383/70383] -> "Trainingdata/Cat/cat-relaxing-1024x576.jpg" [1]
# 2022-09-28 17:59:01 URL:https://img.thrfun.com/img/076/731/hungry_cat_l1.jpg [75166/75166] -> "Trainingdata/Cat/hungry_cat_l1.jpg" [1]
# 2022-09-28 17:59:01 URL:https://wallup.net/wp-content/uploads/2016/01/229502-cat-sleeping-animals.jpg [801709] -> "Trainingdata/Cat/229502-cat-sleeping-animals.jpg" [1]

# %% [markdown]
# ---

# %% [markdown]
# ## Now for the training part

# %%
#First som imports
import torch
import imageio
import torchvision
import torch.nn as nn
import torchvision.transforms as transforms

# %%
# Use the GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Set up augmentation and scaling

# %%
input_shape=(224,224)
transformTrain = transforms.Compose(
    [lambda x: x[:,:,:3], # remove alpha channel
     transforms.ToPILImage(),
     transforms.Resize(input_shape),
     torchvision.transforms.RandomHorizontalFlip(p=0.5),
     transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

transformTest = transforms.Compose(
    [lambda x: x[:,:,:3], # remove alpha channel
     transforms.ToPILImage(),
     transforms.Resize(input_shape),
     transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])


trainset = torchvision.datasets.folder.DatasetFolder(root=traindir, loader=imageio.imread, extensions=['jpg','png','tiff','jpeg'], transform=transformTrain)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=8, shuffle=True, num_workers=0)

# %% [markdown]
# Define network architecture

# %%
num_classes = len(trainset.classes)

# Load existing model (Resnet inetic out with the majority of its major new features. There’s a new ‘Quick Settings’ that makes managing everyday system tasks easier; a resize-friendly Settings app; and ample new features in the Nautilus file manager, including restyled ‘properties’ dialogs and enhanced list view.18)
# Check-out this list: https://pytorch.org/vision/stable/models.html#classification
net = torchvision.models.resnet18(pretrained=True)

# change last layer to reflect the number of classes of our dataset.
num_ftrs = net.fc.in_features
net.fc = nn.Linear(num_ftrs, num_classes)

input_size = 224


# Move network to GPU if available
net.to(device)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %%
# Set-up training
criterion = nn.CrossEntropyLoss()

#optimizer = torch.optim.SGD(net.parameters(), lr=0.01, momentum=0.9, nesterov=True)
optimizer = torch.optim.Adam(net.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)
#optimizer = torch.optim.Adagrad(net.parameters(), lr=0.01, lr_decay=0, weight_decay=0.0005)


#Learning rate updater
#lambda1 = lambda epoch: epoch // 30#New, not tested
#lambda2 = lambda epoch: 0.97 ** epoch#New, not tested
#scheduler = torch.optim.lr_scheduler.LambdaLR(self.optimizer, lr_lambda=lambda2)#New, not tested
#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, verbose=True)

# %% [markdown]
# ## Training loop!

# %%
NUM_EPOCHS = 100
itercounter=0
print_interval=10 #
for epoch in range(NUM_EPOCHS):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):

        net.train() # enable dropout and BatchNorm
        itercounter+=1

        inputs, labels = data
        # Move to GPU (or CPU)
        inputs, labels = inputs.to(device), labels.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()

        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if (itercounter) % print_interval == print_interval-1:    # print every x mini-batches
            print('[epoch: %d, iter: %5d] running loss: %.6f' %
                  (epoch + 1, i + 1, running_loss / 2000))
            running_loss = 0.0
net.eval() # disable dropout and BatchNorm
# Out:
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f2649113790>
# Traceback (most recent call last):
#   File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1358, in __del__
#     self._shutdown_workers()
#   File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1341, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# Exception ignored in: Exception ignored in: Exception ignored in: AssertionError<function _MultiProcessingDataLoaderIter.__del__ at 0x7f2649113790><function _MultiProcessingDataLoaderIter.__del__ at 0x7f2649113790>
#
# Traceback (most recent call last):
#   File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1358, in __del__
# : <function _MultiProcessingDataLoaderIter.__del__ at 0x7f2649113790>can only test a child process
# Traceback (most recent call last):
#   File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1358, in __del__
#         self._shutdown_workers()
# Traceback (most recent call last):
# self._shutdown_workers()
# Exception ignored in:   File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1341, in _shutdown_workers
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f2649113790>
#
# Traceback (most recent call last):
#   File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1341, in _shutdown_workers
#   File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1358, in __del__
# if w.is_alive():          File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1358, in __del__
#
#     self._shutdown_workers()  File "/usr/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# self._shutdown_workers()
#
# if w.is_alive():assert self._parent_pid == os.getpid(), 'can only test a child process'  File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1341, in _shutdown_workers
#
#
# if w.is_alive():
# AssertionError  File "/usr/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#   File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1341, in _shutdown_workers
# :       File "/usr/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     can only test a child processassert self._parent_pid == os.getpid(), 'can only test a child process'
#
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: if w.is_alive():AssertionErrorcan only test a child process
# :
# can only test a child process  File "/usr/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# Exception ignored in:     <function _MultiProcessingDataLoaderIter.__del__ at 0x7f2649113790>
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError
# : Traceback (most recent call last):
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f2649113790>can only test a child processException ignored in:
#   File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1358, in __del__
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f2649113790>Exception ignored in:
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f2649113790>self._shutdown_workers()Traceback (most recent call last):
#
# Traceback (most recent call last):
#   File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1358, in __del__
#   File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1358, in __del__
#
#
#   File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1341, in _shutdown_workers
#     self._shutdown_workers()self._shutdown_workers()Traceback (most recent call last):
#   File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1358, in __del__
#
#
#       File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1341, in _shutdown_workers
#     if w.is_alive():      File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1341, in _shutdown_workers
# if w.is_alive():self._shutdown_workers()
#     if w.is_alive():
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#   File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1341, in _shutdown_workers
#
#
# Exception ignored in: assert self._parent_pid == os.getpid(), 'can only test a child process'Exception ignored in:
# AssertionError:   File "/usr/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# if w.is_alive():<function _MultiProcessingDataLoaderIter.__del__ at 0x7f2649113790>    can only test a child processassert self._parent_pid == os.getpid(), 'can only test a child process'
# Exception ignored in:
# AssertionError
# Traceback (most recent call last):
# : can only test a child process
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f2649113790><function _MultiProcessingDataLoaderIter.__del__ at 0x7f2649113790>
#
#   File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1358, in __del__
#
# AssertionError  File "/usr/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# Traceback (most recent call last):
#     self._shutdown_workers()  File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1358, in __del__
# :
# can only test a child processTraceback (most recent call last):
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#
# AssertionError  File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1341, in _shutdown_workers
#   File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1358, in __del__
# self._shutdown_workers()
#     if w.is_alive()::
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# self._shutdown_workers()can only test a child process  File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1341, in _shutdown_workers
#
#     if w.is_alive():
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f2649113790>assert self._parent_pid == os.getpid(), 'can only test a child process'  File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1341, in _shutdown_workers
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#
# Traceback (most recent call last):
#
#
# AssertionError  File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1358, in __del__
# if w.is_alive():assert self._parent_pid == os.getpid(), 'can only test a child process'
#
# AssertionError:   File "/usr/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# :     can only test a child process    can only test a child processself._shutdown_workers()
#
#
# assert self._parent_pid == os.getpid(), 'can only test a child process'  File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1341, in _shutdown_workers
#
# AssertionError    if w.is_alive():: can only test a child process
#
# Exception ignored in:   File "/usr/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f2649113790>
#     Traceback (most recent call last):
# assert self._parent_pid == os.getpid(), 'can only test a child process'Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f2649113790>
# Exception ignored in:   File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1358, in __del__
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f2649113790>
# AssertionError    : self._shutdown_workers()
# can only test a child processTraceback (most recent call last):
#
# Traceback (most recent call last):
#   File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1341, in _shutdown_workers
#
#   File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1358, in __del__
#       File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1358, in __del__
# if w.is_alive():
# self._shutdown_workers()self._shutdown_workers()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#
#       File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1341, in _shutdown_workers
#   File "/home/mads/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1341, in _shutdown_workers
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionErrorif w.is_alive():: if w.is_alive():
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     can only test a child process
#
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
# assert self._parent_pid == os.getpid(), 'can only test a child process'
#     AssertionErrorassert self._parent_pid == os.getpid(), 'can only test a child process':
# can only test a child processAssertionError: can only test a child process
# [epoch: 1, iter:     9] loss: 0.001091
# [epoch: 1, iter:    19] loss: 0.001077
# [epoch: 1, iter:    29] loss: 0.001302
# [epoch: 2, iter:     3] loss: 0.000400
# [epoch: 2, iter:    13] loss: 0.003485
# [epoch: 2, iter:    23] loss: 0.001241
# [epoch: 2, iter:    33] loss: 0.001755
# [epoch: 3, iter:     7] loss: 0.000915
# [epoch: 3, iter:    17] loss: 0.001085
# [epoch: 3, iter:    27] loss: 0.000908
# [epoch: 4, iter:     1] loss: 0.000009
# [epoch: 4, iter:    11] loss: 0.000627
# [epoch: 4, iter:    21] loss: 0.001554
# [epoch: 4, iter:    31] loss: 0.000754
# [epoch: 5, iter:     5] loss: 0.000471
# [epoch: 5, iter:    15] loss: 0.001443
# [epoch: 5, iter:    25] loss: 0.000807
# [epoch: 5, iter:    35] loss: 0.001297
# [epoch: 6, iter:     9] loss: 0.000745
# [epoch: 6, iter:    19] loss: 0.000732
# [epoch: 6, iter:    29] loss: 0.000920
# [epoch: 7, iter:     3] loss: 0.000270
# [epoch: 7, iter:    13] loss: 0.001166
# [epoch: 7, iter:    23] loss: 0.000688
# [epoch: 7, iter:    33] loss: 0.001766
# [epoch: 8, iter:     7] loss: 0.000702
# [epoch: 8, iter:    17] loss: 0.001048
# [epoch: 8, iter:    27] loss: 0.000794
# [epoch: 9, iter:     1] loss: 0.000042
# [epoch: 9, iter:    11] loss: 0.000712
# [epoch: 9, iter:    21] loss: 0.000692
# [epoch: 9, iter:    31] loss: 0.001396
# [epoch: 10, iter:     5] loss: 0.000188
# [epoch: 10, iter:    15] loss: 0.000275
# [epoch: 10, iter:    25] loss: 0.000811
# [epoch: 10, iter:    35] loss: 0.000999
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %% [markdown]
# ## Let's evaluate the model on some training data

# %%
# Test the model
import imageio
import numpy as np
image = imageio.imread('Testdata/cat_image.jpg')

def softmax(x):
    """Compute softmax values for each sets of scores in x."""
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum()

imagetransformed = transformTest(image)
if len(imagetransformed.shape)==3:
    imagetransformed = imagetransformed.unsqueeze(0)

imagetransformed = imagetransformed.to(device)

outputs = net(imagetransformed)
#_, predicted = torch.max(outputs.data, 1)

output_prob = outputs.data.tolist()[0]

softmaxOutput = True
if softmaxOutput:
    output_prob = softmax(output_prob)
    #print(output_prob)
# Out:
# [0.68716772 0.31283228]

# %%
print('Prediction:', trainset.classes[np.argmax(output_prob)])
# Out:
# Prediction: Cat
